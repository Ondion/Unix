# %% [markdown]
# <h1 style="text-align: center;">Estrutura de Dados</h1>
# <hr>

# %% [markdown]
# *_Estrutura organizada de dados na memória de um computador, de forma que os dados possam ser utilizados de forma correta._*
